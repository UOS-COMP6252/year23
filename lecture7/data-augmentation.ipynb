# %%
import torch
import torchvision
from torchvision.transforms import TrivialAugmentWide,AugMix,AutoAugment,RandAugment,RandomHorizontalFlip,Resize,ToTensor,Compose,RandomCrop,RandomRotation,Normalize,CenterCrop
from torch.utils.data import DataLoader,Dataset, random_split
#transform=torchvision.transforms.RandomHorizontalFlip()
#transform=torchvision.transforms.RandomAffine(degrees=0,translate=(0.5,0.5))
#dataset=torchvision.datasets.ImageFolder("flowers",transform=transform)
dataset=torchvision.datasets.ImageFolder("flower_photos")

# %%
seed=9 #67 after 30 epochs with no aug.

torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True

# %%
class MyDataset(Dataset):
    def __init__(self,subset,transform=None):
        self.subset=subset
        self.transform=transform
    def __getitem__(self,idx):
        x,y=self.subset[idx]
        if self.transform:
            x=self.transform(x)
        return x,y
    def __len__(self):
        return len(self.subset)

# %%
len(dataset)
# Out:
# 3670

# %%
#train_d,valid_d,test_d=random_split(dataset,lengths=[0.7,0.2,0.1])
train_d,valid_d=random_split(dataset,lengths=[0.8,0.2])

# %%
augment_choices={'horizontal':RandomHorizontalFlip(0.8),'trivial':TrivialAugmentWide(),'random':RandAugment(),'mix':AugMix(),'auto':AutoAugment()}
#train_t=Compose([RandomHorizontalFlip(),Resize((180,180)),ToTensor()])
augmentation='trivial'
valid_t=Compose([Resize((180,180)),ToTensor()])
if augmentation=='None':
    train_t=valid_t
else:
    train_t=Compose([augment_choices[augmentation],Resize((180,180)),ToTensor()])

# %%
train_dt=MyDataset(train_d,train_t)
valid_dt=MyDataset(valid_d,valid_t)
#test_dt=MyDataset(test_d,test_t)

# %%
train_loader=DataLoader(train_dt,batch_size=32,shuffle=True,num_workers=2)
valid_loader=DataLoader(valid_dt,batch_size=32,shuffle=False,num_workers=2)

# %%
itr=iter(train_loader)
imgs,labels=next(itr)

# %%
from torch import nn
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.relu=nn.ReLU()
        #[3, 224, 224]
        self.conv1=nn.Conv2d(in_channels=3,out_channels=16,kernel_size=3)
        # [16,222,222]
        self.conv2=nn.Conv2d(in_channels=16,out_channels=16,kernel_size=3)
        #[16,220,220]
        self.pool1=nn.MaxPool2d(kernel_size=2)
        #[16,110,110]
        self.norm1=nn.BatchNorm2d(num_features=16)
        
        self.conv3=nn.Conv2d(in_channels=16,out_channels=32,kernel_size=3)
         #[32,108,108]
        self.conv4=nn.Conv2d(in_channels=32,out_channels=32,kernel_size=3)
        #[32,106,106]
        self.pool2=nn.MaxPool2d(kernel_size=2)
        #[32,53,53]
        self.norm2=nn.BatchNorm2d(num_features=32)
        
        
        self.conv5=nn.Conv2d(in_channels=32,out_channels=32,kernel_size=3)
        self.conv6=nn.Conv2d(in_channels=32,out_channels=32,kernel_size=3,padding="same")
         #[32,51,51]
        self.pool3=nn.MaxPool2d(kernel_size=2)
        #[32,25,25]
        self.norm3=nn.BatchNorm2d(num_features=32)
        
        #self.fc1=nn.Linear(in_features=89888,out_features=256)
        self.fc1=nn.Linear(in_features=20000,out_features=256)
        self.fc2=nn.Linear(in_features=256,out_features=5)
    def forward(self,x):
        x=self.conv1(x)
        x=self.relu(x)
        x=self.conv2(x)
        x=self.relu(x)
        x=self.pool1(x)
       # x=self.norm1(x)
        
        x=self.conv3(x)
        x=self.relu(x)
        x=self.conv4(x)
        x=self.relu(x)
        x=self.pool2(x)
       # x=self.norm2(x)
        
        x=self.conv5(x)
        x=self.relu(x)
        x=self.conv6(x)
        x=self.relu(x)
        x=self.pool3(x)
        #x=self.norm3(x)
        x=x.flatten(start_dim=1)
        x=self.fc1(x)
        x=self.relu(x)
        x=self.fc2(x)
        return x

# %%
class Model2(nn.Module):
    def __init__(self):
        super().__init__()
        #(3,180,180)
        self.conv1=nn.Conv2d(in_channels=3,out_channels=16,kernel_size=3,padding='same')
        self.pool1=nn.MaxPool2d(2)
        #(16,90,90)
        self.conv2=nn.Conv2d(in_channels=16,out_channels=32,kernel_size=3,padding='same')
        self.pool2=nn.MaxPool2d(2)
        #(32,45,45)
        self.conv3=nn.Conv2d(in_channels=32,out_channels=64,kernel_size=3,padding='same')
        self.pool3=nn.MaxPool2d(2)
        #(64,22,22)
        self.relu=nn.ReLU()
        self.drop=nn.Dropout(0.2)
        self.fc1=nn.Linear(in_features=64*22*22,out_features=128)
        self.fc2=nn.Linear(in_features=128,out_features=5)
    def forward(self,x):
        x=self.conv1(x)
        x=self.relu(x)
        x=self.pool1(x)
        x=self.conv2(x)
        x=self.relu(x)
        x=self.pool2(x)
        x=self.conv3(x)
        x=self.relu(x)
        x=self.pool3(x)
        #x=self.drop(x)
        x=x.view(x.size()[0],-1)
        x=self.fc1(x)
        x=self.relu(x)
        x=self.fc2(x)
        return x

# %%
model=Model2()

# %%
def accuracy(model,batch,loss_fn):
    imgs,labels=batch
    imgs=imgs.cuda()
    labels=labels.cuda()
    outputs=model(imgs)
    _,pred=torch.max(outputs,dim=1)
    acc=torch.sum(pred==labels).item()
    loss=loss_fn(outputs,labels)
    return loss,torch.tensor(acc),len(labels)

@torch.no_grad() 
def evaluate(model,loader,loss_fn):
    model.eval()
    # crit is a list of pairs of tensors
    crit=[accuracy(model,batch,loss_fn) for batch in loader]
    crit=torch.tensor(crit)
    m=crit.mean(dim=0)
    loss=m[0]
    acc=m[1]
    bsize=m[2]
    return loss/bsize,acc/bsize

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
# %load_ext tensorboard
current=datetime.datetime.now()
log_dir = 'logs/tensorboard/' +augmentation+'-'+current.strftime("%c")
writer=SummaryWriter(log_dir)

# %%
from torch.optim import Adam
loss_fn=nn.CrossEntropyLoss()
optimizer=Adam(model.parameters())
model=model.cuda()
epochs=1000
for epoch in range(epochs):
    model.train()
    epoch_loss=0.
    for imgs,labels in train_loader:
        imgs=imgs.cuda()
        labels=labels.cuda()
        outputs=model(imgs)
        loss=loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        epoch_loss=0.9*epoch_loss+0.1*loss.item()
    vl,va=evaluate(model,valid_loader,loss_fn)
    tl,ta=evaluate(model,train_loader,loss_fn)
    writer.add_scalar("Epoch loss",epoch_loss,epoch)
    writer.add_scalars("loss",{'train':tl,'valid':vl},epoch)
    writer.add_scalars("acc",{'train':ta,'valid':va},epoch)
    if epoch%10==0:
        print("Epoch[{}]".format(epoch))
        print("Train: loss={:.4f}, accuracy={:.4f}".format(tl,ta))
        print("Valid: loss={:.4f}, accuracy={:.4f}".format(vl,va))
        print("----------------------")
writer.close()
# Out:
# Epoch[0]
# Train: loss=0.0385, accuracy=0.4693
# Valid: loss=0.0358, accuracy=0.5123
# ----------------------
# Epoch[10]
# Train: loss=0.0227, accuracy=0.7231
# Valid: loss=0.0261, accuracy=0.6839
# ----------------------
# Epoch[20]
# Train: loss=0.0133, accuracy=0.8501
# Valid: loss=0.0268, accuracy=0.7234
# ----------------------
# Epoch[30]
# Train: loss=0.0117, accuracy=0.8713
# Valid: loss=0.0293, accuracy=0.7384
# ----------------------
# Epoch[40]
# Train: loss=0.0105, accuracy=0.8753
# Valid: loss=0.0339, accuracy=0.7221
# ----------------------
# Epoch[50]
# Train: loss=0.0095, accuracy=0.8965
# Valid: loss=0.0276, accuracy=0.7330
# ----------------------
# Epoch[60]
# Train: loss=0.0080, accuracy=0.9097
# Valid: loss=0.0317, accuracy=0.7044
# ----------------------
# Epoch[70]
# Train: loss=0.0070, accuracy=0.9223
# Valid: loss=0.0322, accuracy=0.7452
# ----------------------
# Epoch[80]
# Train: loss=0.0078, accuracy=0.9142
# Valid: loss=0.0330, accuracy=0.7275
# ----------------------
# Epoch[90]
# Train: loss=0.0074, accuracy=0.9176
# Valid: loss=0.0382, accuracy=0.7275
# ----------------------
# Epoch[100]
# Train: loss=0.0060, accuracy=0.9346
# Valid: loss=0.0331, accuracy=0.7439
# ----------------------
# Epoch[110]
# Train: loss=0.0065, accuracy=0.9268
# Valid: loss=0.0348, accuracy=0.7411
# ----------------------
# Epoch[120]
# Train: loss=0.0062, accuracy=0.9315
# Valid: loss=0.0356, accuracy=0.7357
# ----------------------
# Epoch[130]
# Train: loss=0.0058, accuracy=0.9336
# Valid: loss=0.0357, accuracy=0.7221
# ----------------------
# Epoch[140]
# Train: loss=0.0047, accuracy=0.9475
# Valid: loss=0.0343, accuracy=0.7534
# ----------------------
# Epoch[150]
# Train: loss=0.0065, accuracy=0.9261
# Valid: loss=0.0376, accuracy=0.7289
# ----------------------
# Epoch[160]
# Train: loss=0.0056, accuracy=0.9397
# Valid: loss=0.0373, accuracy=0.7452
# ----------------------
# Epoch[170]
# Train: loss=0.0049, accuracy=0.9431
# Valid: loss=0.0330, accuracy=0.7548
# ----------------------
# Epoch[180]
# Train: loss=0.0053, accuracy=0.9377
# Valid: loss=0.0347, accuracy=0.7371
# ----------------------
# Epoch[190]
# Train: loss=0.0046, accuracy=0.9455
# Valid: loss=0.0349, accuracy=0.7507
# ----------------------
# Epoch[200]
# Train: loss=0.0050, accuracy=0.9428
# Valid: loss=0.0400, accuracy=0.7343
# ----------------------
# Epoch[210]
# Train: loss=0.0046, accuracy=0.9465
# Valid: loss=0.0352, accuracy=0.7316
# ----------------------
# Epoch[220]
# Train: loss=0.0048, accuracy=0.9475
# Valid: loss=0.0399, accuracy=0.7507
# ----------------------
# Epoch[230]
# Train: loss=0.0051, accuracy=0.9438
# Valid: loss=0.0382, accuracy=0.7480
# ----------------------
# Epoch[240]
# Train: loss=0.0049, accuracy=0.9431
# Valid: loss=0.0431, accuracy=0.7466
# ----------------------
# Epoch[250]
# Train: loss=0.0044, accuracy=0.9503
# Valid: loss=0.0449, accuracy=0.7357
# ----------------------
# Epoch[260]
# Train: loss=0.0048, accuracy=0.9452
# Valid: loss=0.0419, accuracy=0.7316
# ----------------------
# Epoch[270]
# Train: loss=0.0044, accuracy=0.9506
# Valid: loss=0.0442, accuracy=0.7439
# ----------------------
# Epoch[280]
# Train: loss=0.0043, accuracy=0.9530
# Valid: loss=0.0382, accuracy=0.7561
# ----------------------
# Epoch[290]
# Train: loss=0.0040, accuracy=0.9574
# Valid: loss=0.0412, accuracy=0.7684
# ----------------------
# Epoch[300]
# Train: loss=0.0034, accuracy=0.9629
# Valid: loss=0.0426, accuracy=0.7548
# ----------------------
# Epoch[310]
# Train: loss=0.0037, accuracy=0.9601
# Valid: loss=0.0427, accuracy=0.7534
# ----------------------
# Epoch[320]
# Train: loss=0.0034, accuracy=0.9595
# Valid: loss=0.0431, accuracy=0.7398
# ----------------------
# Epoch[330]
# Train: loss=0.0046, accuracy=0.9527
# Valid: loss=0.0460, accuracy=0.7520
# ----------------------
# Epoch[340]
# Train: loss=0.0035, accuracy=0.9619
# Valid: loss=0.0465, accuracy=0.7616
# ----------------------
# Epoch[350]
# Train: loss=0.0036, accuracy=0.9561
# Valid: loss=0.0399, accuracy=0.7684
# ----------------------
# Epoch[360]
# Train: loss=0.0030, accuracy=0.9666
# Valid: loss=0.0428, accuracy=0.7616
# ----------------------
# Epoch[370]
# Train: loss=0.0036, accuracy=0.9622
# Valid: loss=0.0435, accuracy=0.7684
# ----------------------
# Epoch[380]
# Train: loss=0.0031, accuracy=0.9629
# Valid: loss=0.0458, accuracy=0.7493
# ----------------------
# Epoch[390]
# Train: loss=0.0037, accuracy=0.9581
# Valid: loss=0.0435, accuracy=0.7602
# ----------------------
# Epoch[400]
# Train: loss=0.0032, accuracy=0.9649
# Valid: loss=0.0471, accuracy=0.7589
# ----------------------
# Epoch[410]
# Train: loss=0.0033, accuracy=0.9687
# Valid: loss=0.0454, accuracy=0.7561
# ----------------------
# Epoch[420]
# Train: loss=0.0033, accuracy=0.9625
# Valid: loss=0.0508, accuracy=0.7670
# ----------------------
# Epoch[430]
# Train: loss=0.0026, accuracy=0.9707
# Valid: loss=0.0469, accuracy=0.7602
# ----------------------
# Epoch[440]
# Train: loss=0.0027, accuracy=0.9700
# Valid: loss=0.0477, accuracy=0.7670
# ----------------------
# Epoch[450]
# Train: loss=0.0027, accuracy=0.9707
# Valid: loss=0.0460, accuracy=0.7575
# ----------------------
# Epoch[460]
# Train: loss=0.0028, accuracy=0.9700
# Valid: loss=0.0481, accuracy=0.7698
# ----------------------
# Epoch[470]
# Train: loss=0.0032, accuracy=0.9622
# Valid: loss=0.0437, accuracy=0.7657
# ----------------------
# Epoch[480]
# Train: loss=0.0030, accuracy=0.9612
# Valid: loss=0.0441, accuracy=0.7752
# ----------------------
# Epoch[490]
# Train: loss=0.0026, accuracy=0.9687
# Valid: loss=0.0458, accuracy=0.7711
# ----------------------
# Epoch[500]
# Train: loss=0.0028, accuracy=0.9700
# Valid: loss=0.0434, accuracy=0.7766
# ----------------------
# Epoch[510]
# Train: loss=0.0028, accuracy=0.9693
# Valid: loss=0.0412, accuracy=0.7684
# ----------------------
# Epoch[520]
# Train: loss=0.0027, accuracy=0.9697
# Valid: loss=0.0414, accuracy=0.7956
# ----------------------
# Epoch[530]
# Train: loss=0.0036, accuracy=0.9619
# Valid: loss=0.0569, accuracy=0.7480
# ----------------------
# Epoch[540]
# Train: loss=0.0022, accuracy=0.9741
# Valid: loss=0.0452, accuracy=0.7629
# ----------------------
# Epoch[550]
# Train: loss=0.0033, accuracy=0.9687
# Valid: loss=0.0522, accuracy=0.7452
# ----------------------
# Epoch[560]
# Train: loss=0.0035, accuracy=0.9629
# Valid: loss=0.0466, accuracy=0.7698
# ----------------------
# Epoch[570]
# Train: loss=0.0027, accuracy=0.9710
# Valid: loss=0.0490, accuracy=0.7684
# ----------------------
# Epoch[580]
# Train: loss=0.0023, accuracy=0.9707
# Valid: loss=0.0489, accuracy=0.7684
# ----------------------
# Epoch[590]
# Train: loss=0.0030, accuracy=0.9653
# Valid: loss=0.0556, accuracy=0.7316
# ----------------------
# Epoch[600]
# Train: loss=0.0028, accuracy=0.9676
# Valid: loss=0.0528, accuracy=0.7316
# ----------------------
# Epoch[610]
# Train: loss=0.0026, accuracy=0.9690
# Valid: loss=0.0498, accuracy=0.7793
# ----------------------
# Epoch[620]
# Train: loss=0.0034, accuracy=0.9646
# Valid: loss=0.0473, accuracy=0.7725
# ----------------------
# Epoch[630]
# Train: loss=0.0023, accuracy=0.9762
# Valid: loss=0.0473, accuracy=0.7534
# ----------------------
# Epoch[640]
# Train: loss=0.0024, accuracy=0.9748
# Valid: loss=0.0549, accuracy=0.7670
# ----------------------
# Epoch[650]
# Train: loss=0.0025, accuracy=0.9687
# Valid: loss=0.0484, accuracy=0.7725
# ----------------------
# Epoch[660]
# Train: loss=0.0030, accuracy=0.9636
# Valid: loss=0.0558, accuracy=0.7548
# ----------------------
# Epoch[670]
# Train: loss=0.0024, accuracy=0.9738
# Valid: loss=0.0520, accuracy=0.7793
# ----------------------
# Epoch[680]
# Train: loss=0.0024, accuracy=0.9714
# Valid: loss=0.0487, accuracy=0.7698
# ----------------------
# Epoch[690]
# Train: loss=0.0025, accuracy=0.9728
# Valid: loss=0.0497, accuracy=0.7548
# ----------------------
# Epoch[700]
# Train: loss=0.0023, accuracy=0.9745
# Valid: loss=0.0538, accuracy=0.7657
# ----------------------
# Epoch[710]
# Train: loss=0.0025, accuracy=0.9700
# Valid: loss=0.0553, accuracy=0.7561
# ----------------------
# Epoch[720]
# Train: loss=0.0023, accuracy=0.9724
# Valid: loss=0.0646, accuracy=0.7534
# ----------------------
# Epoch[730]
# Train: loss=0.0025, accuracy=0.9728
# Valid: loss=0.0595, accuracy=0.7575
# ----------------------
# Epoch[740]
# Train: loss=0.0026, accuracy=0.9751
# Valid: loss=0.0715, accuracy=0.7452
# ----------------------
# Epoch[750]
# Train: loss=0.0022, accuracy=0.9765
# Valid: loss=0.0518, accuracy=0.7548
# ----------------------
# Epoch[760]
# Train: loss=0.0026, accuracy=0.9751
# Valid: loss=0.0565, accuracy=0.7698
# ----------------------
# Epoch[770]
# Train: loss=0.0030, accuracy=0.9676
# Valid: loss=0.0576, accuracy=0.7766
# ----------------------
# Epoch[780]
# Train: loss=0.0018, accuracy=0.9826
# Valid: loss=0.0552, accuracy=0.7711
# ----------------------
# Epoch[790]
# Train: loss=0.0023, accuracy=0.9734
# Valid: loss=0.0605, accuracy=0.7602
# ----------------------
# Epoch[800]
# Train: loss=0.0021, accuracy=0.9755
# Valid: loss=0.0583, accuracy=0.7779
# ----------------------
# Epoch[810]
# Train: loss=0.0020, accuracy=0.9772
# Valid: loss=0.0560, accuracy=0.7711
# ----------------------
# Epoch[820]
# Train: loss=0.0018, accuracy=0.9779
# Valid: loss=0.0533, accuracy=0.7752
# ----------------------
# Epoch[830]
# Train: loss=0.0021, accuracy=0.9779
# Valid: loss=0.0651, accuracy=0.7643
# ----------------------
# Epoch[840]
# Train: loss=0.0021, accuracy=0.9779
# Valid: loss=0.0650, accuracy=0.7643
# ----------------------
# Epoch[850]
# Train: loss=0.0022, accuracy=0.9772
# Valid: loss=0.0593, accuracy=0.7766
# ----------------------
# Epoch[860]
# Train: loss=0.0016, accuracy=0.9823
# Valid: loss=0.0620, accuracy=0.7657
# ----------------------
# Epoch[870]
# Train: loss=0.0020, accuracy=0.9789
# Valid: loss=0.0622, accuracy=0.7520
# ----------------------
# Epoch[880]
# Train: loss=0.0017, accuracy=0.9806
# Valid: loss=0.0559, accuracy=0.7820
# ----------------------
# Epoch[890]
# Train: loss=0.0018, accuracy=0.9782
# Valid: loss=0.0506, accuracy=0.7929
# ----------------------
# Epoch[900]
# Train: loss=0.0020, accuracy=0.9779
# Valid: loss=0.0555, accuracy=0.7752
# ----------------------
# Epoch[910]
# Train: loss=0.0023, accuracy=0.9728
# Valid: loss=0.0500, accuracy=0.7643
# ----------------------
# Epoch[920]
# Train: loss=0.0020, accuracy=0.9785
# Valid: loss=0.0538, accuracy=0.7766
# ----------------------
# Epoch[930]
# Train: loss=0.0019, accuracy=0.9789
# Valid: loss=0.0597, accuracy=0.7738
# ----------------------
# Epoch[940]
# Train: loss=0.0015, accuracy=0.9819
# Valid: loss=0.0586, accuracy=0.7343
# ----------------------
# Epoch[950]
# Train: loss=0.0020, accuracy=0.9785
# Valid: loss=0.0597, accuracy=0.7589
# ----------------------
# Epoch[960]
# Train: loss=0.0025, accuracy=0.9741
# Valid: loss=0.0633, accuracy=0.7670
# ----------------------
# Epoch[970]
# Train: loss=0.0017, accuracy=0.9830
# Valid: loss=0.0609, accuracy=0.7493
# ----------------------
# Epoch[980]
# Train: loss=0.0021, accuracy=0.9809
# Valid: loss=0.0637, accuracy=0.7616
# ----------------------
# Epoch[990]
# Train: loss=0.0020, accuracy=0.9768
# Valid: loss=0.0713, accuracy=0.7425
# ----------------------

# %%
# %tensorboard --logdir logs/tensorboard
# Out:
# Reusing TensorBoard on port 6007 (pid 2216015), started 1 day, 19:24:05 ago. (Use '!kill 2216015' to kill it.)
#       <iframe id="tensorboard-frame-e14051b6d43e8f9b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e14051b6d43e8f9b");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
