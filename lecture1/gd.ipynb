# %%
import matplotlib.pyplot as plt
#%matplotlib notebook
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
#fig,ax=plt.subplots()
#an=FuncAnimation(fig, animate, frames=80, interval=500, repeat=False)
#plt.show()
#writer = animation.PillowWriter(fps=3,
#                                 metadata=dict(artist='Me'),
#                                 bitrate=1800)
#an.save('gd.gif', writer=writer)

# %%
# %matplotlib notebook
def func(i):
    return 0.1*(i-5)**2+2
def grad(a):
    return 0.2*(a-5)

px=[-1]
rate=.3
for i in range(-50,150):
    last=px[-1]
    px.append(last-rate*grad(last))

py=[func(p) for p in px]
xs=[0.1*i for i in range(-50,150)]
ys=[func(i) for i in v]
fig,ax=plt.subplots()
def animate(i):
    ax.clear()
    ax.plot(xs,ys)
    c=plt.Circle((px[i],py[i]),0.2,color='red')
    #ax.plot(px,py,'o',color='red')
    ax.add_artist(c)
    #ax.plot([px[i],px[i]],[py[i],0],'r:')
    ax.plot([5,5],[func(5),0],'r:')
    #if i>0:
    #     ax.plot([px[i-1],px[i-1]],[py[i-1],0],'r:')
    ax.set_ylim(0)
    ax.set_title("Low rate")
    ax.set_xlabel("parameter")
    ax.set_ylabel("loss")
    if i>18:
        plt.text(3,5,"After 20 steps")
    

an=FuncAnimation(fig, animate, frames=20, interval=1000, repeat=False)
writer = animation.PillowWriter(fps=3,
                                 metadata=dict(artist='Me'),
                                 bitrate=800)
an.save('low-rate.gif', writer=writer)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
